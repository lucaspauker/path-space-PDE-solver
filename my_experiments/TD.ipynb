# %%
# %matplotlib inline

import copy
from datetime import date
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import sys
import time
import torch as pt

sys.path.insert(0, '..')

from function_space import DenseNet, DenseNet_tanh
from problems import ExponentialOnBallNonlinearSin
from solver import EllipticSolver
from utilities import plot_loss_logs_extended, plot_moving_average

# %load_ext autoreload
# %autoreload 2

device = pt.device('cuda')

# %%
pt.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
d = 50
L = 220000
print_every = 500
delta_t = 0.001
N = 20

problem = ExponentialOnBallNonlinearSin(d=d)

model_td = EllipticSolver(problem, 'TD', seed=42, delta_t=delta_t, N=N, lr=0.001, L=L, K=200, K_test_log=10000,
                 K_boundary=50, alpha=[0.1, 1.0], adaptive_forward_process=False, detach_forward=True,
                 print_every=print_every, verbose=True, approx_method='Y', sample_center=False, loss_method='td')

model_td.V = DenseNet(d, 1, 0.001, arch=[d + 20, d, d, d]).to(device)
    
start = time.time()
model_td.train()
end = time.time()
print(end - start)
# Out:
# /home/ubuntu/CS332/path-space-PDE-solver/my_experiments/../solver.py:738: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   V_L2[selection.cpu()] += ((self.V(X[selection]).squeeze() - pt.tensor(self.problem.v_true(X[selection].detach())).float().squeeze())**2).detach().cpu() * self.delta_t_np
# 0 - loss = 3.9342e+01, v L2 error = 1.8510e-02, n = 7, active: 0/200, 0.71
# 500 - loss = 7.6178e+00, v L2 error = 1.9090e-02, n = 10, active: 0/200, 0.05
# 1000 - loss = 7.4040e+00, v L2 error = 1.8218e-02, n = 6, active: 0/200, 0.05
# 1500 - loss = 7.4100e+00, v L2 error = 1.8323e-02, n = 6, active: 0/200, 0.05
# 2000 - loss = 7.3938e+00, v L2 error = 1.7993e-02, n = 6, active: 0/200, 0.05
# 2500 - loss = 7.3985e+00, v L2 error = 1.8699e-02, n = 7, active: 0/200, 0.05
# ...

# %%
import pickle

# %%
with open('../TD_Model_Correct_TD_112922.pickle', 'wb') as f:
    pickle.dump(model_td, f, protocol=pickle.DEFAULT_PROTOCOL)

# %%
d = 50
L = 220000
print_every = 500
delta_t = 0.01
N = 20

problem = ExponentialOnBallNonlinearSin(d=d)

model_td = EllipticSolver(problem, 'TD', seed=42, delta_t=delta_t, N=N, lr=0.001, L=L, K=200, K_test_log=10000,
                 K_boundary=50, alpha=[0.1, 1.0], adaptive_forward_process=False, detach_forward=True,
                 print_every=print_every, verbose=True, approx_method='Y', sample_center=False, loss_method='td')

model_td.V = DenseNet(d, 1, 0.001, arch=[d + 20, d, d, d]).to(device)
    
start = time.time()
model_td.train()
end = time.time()
print(end - start)
# Out:
# /home/ubuntu/CS332/path-space-PDE-solver/my_experiments/../solver.py:743: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if self.detach_forward is True:
# 0 - loss = 1.8709e+01, v L2 error = 7.1943e-01, n = 3, active: 0/200, 0.06
# 500 - loss = 7.3821e+00, v L2 error = 7.5119e-01, n = 2, active: 0/200, 0.03
# 1000 - loss = 7.3618e+00, v L2 error = 6.9635e-01, n = 2, active: 0/200, 0.03
# 1500 - loss = 7.3539e+00, v L2 error = 7.1542e-01, n = 2, active: 0/200, 0.03
# 2000 - loss = 7.3403e+00, v L2 error = 6.6901e-01, n = 2, active: 0/200, 0.03
# 2500 - loss = 7.3372e+00, v L2 error = 7.7243e-01, n = 2, active: 0/200, 0.03
# 3000 - loss = 7.3374e+00, v L2 error = 6.7266e-01, n = 2, active: 0/200, 0.03
# 3500 - loss = 7.3333e+00, v L2 error = 6.4771e-01, n = 2, active: 0/200, 0.03
# ...

# %%
with open('../TD_Model_delta_t_01_112922.pickle', 'wb') as f:
    pickle.dump(model_td, f, protocol=pickle.DEFAULT_PROTOCOL)

# %%
d = 50
L = 220000
print_every = 500
delta_t = 0.1
N = 20

problem = ExponentialOnBallNonlinearSin(d=d)

model_td = EllipticSolver(problem, 'TD', seed=42, delta_t=delta_t, N=N, lr=0.001, L=L, K=200, K_test_log=10000,
                 K_boundary=50, alpha=[0.1, 1.0], adaptive_forward_process=False, detach_forward=True,
                 print_every=print_every, verbose=True, approx_method='Y', sample_center=False, loss_method='td')

model_td.V = DenseNet(d, 1, 0.001, arch=[d + 20, d, d, d]).to(device)
    
start = time.time()
model_td.train()
end = time.time()
print(end - start)
# Out:
# /home/ubuntu/CS332/path-space-PDE-solver/my_experiments/../solver.py:743: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   V_L2[selection.cpu()] += ((self.V(X[selection]).squeeze() - pt.tensor(self.problem.v_true(X[selection].detach())).float().squeeze())**2).detach().cpu() * self.delta_t_np
# 0 - loss = 1.8672e+01, v L2 error = 3.5148e+11, n = 2, active: 0/200, 0.98
# 500 - loss = 7.3252e+00, v L2 error = 6.2970e+12, n = 2, active: 0/200, 0.04
# 1000 - loss = 7.1523e+00, v L2 error = 2.1917e+13, n = 2, active: 0/200, 0.04
# 1500 - loss = 6.5616e+00, v L2 error = 1.0850e+12, n = 2, active: 0/200, 0.05
# 2000 - loss = 3.2600e+00, v L2 error = 1.6730e+11, n = 2, active: 0/200, 0.05
# 2500 - loss = 1.4802e+00, v L2 error = 6.6611e+11, n = 2, active: 0/200, 0.05
# ...

# %%
with open('../TD_Model_delta_t_1_112922.pickle', 'wb') as f:
    pickle.dump(model_td, f, protocol=pickle.DEFAULT_PROTOCOL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 with open('../TD_Model_delta_t_1_112922.pickle', 'wb') as f:
# ----> 2     pickle.dump(model_td, f, protocol=pickle.DEFAULT_PROTOCOL)
#
# NameError: name 'pickle' is not defined
